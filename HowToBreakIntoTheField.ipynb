# %% [markdown]
# First, let's take a look at the data, and see how we might answer the first question about how to break into the field of becoming a data scientist according to the survey results.
#
# To get started, let's read in the necessary libraries we will need to wrangle our data: pandas and numpy.  If we decided to build some basic plots, matplotlib might prove useful as well.

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Multiple choice dataframe
mc_df = pd.read_csv('./datasets/multiple_choice_responses.csv')
mc_df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                     France
# 2                                      India
# 3                                    Germany
# 4                                  Australia
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Master’s degree
# 2                                Professional degree
# 3                                Professional degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                  Software Engineer
# 2                                  Software Engineer
# 3                                                NaN
# 4                                              Other
#
#                                        Q5_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                  0
#
#                                                   Q6  \
# 0  What is the size of the company where you are ...
# 1                               1000-9,999 employees
# 2                                 > 10,000 employees
# 3                                                NaN
# 4                                 > 10,000 employees
#
#                                                   Q7  ...  \
# 0  Approximately how many individuals are respons...  ...
# 1                                                  0  ...
# 2                                                20+  ...
# 3                                                NaN  ...
# 4                                                20+  ...
#
#                                           Q34_Part_4  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_5  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_6  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_7  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_8  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q34_Part_9  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 Azure SQL Database
#
#                                          Q34_Part_10  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_11  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Q34_Part_12  \
# 0  Which of the following relational database pro...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q34_OTHER_TEXT
# 0  Which of the following relational database pro...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 246 columns]

# %% [markdown]
# As we can see, people of various professional backgrounds answered the Kaggle survey

# %%
mc_df.Q5.value_counts()
# Out:
# Data Scientist                                                                                             4085
# Student                                                                                                    4014
# Software Engineer                                                                                          2705
# Other                                                                                                      1690
# Data Analyst                                                                                               1598
# Research Scientist                                                                                         1470
# Not employed                                                                                                942
# Business Analyst                                                                                            778
# Product/Project Manager                                                                                     723
# Data Engineer                                                                                               624
# Statistician                                                                                                322
# DBA/Database Engineer                                                                                       156
# Select the title most similar to your current role (or most recent title if retired): - Selected Choice       1
# Name: Q5, dtype: int64

# %% [markdown]
# Let's narrow it down to just data scientists who are employed

# %%
ds_df = mc_df[mc_df['Q5'] == 'Data Scientist']             # Only data scientists
ds_df = ds_df[~ds_df['Q11'].isin(['$0 (USD)', '$1-$99'])]  # Only those are are employed

ds_df
# Out:
#       Time from Start to Finish (seconds)     Q1                 Q2  \
# 6                                     470  50-54               Male
# 7                                     529  22-24               Male
# 13                                    397  30-34               Male
# 32                                    538  30-34               Male
# 35                                    448  22-24               Male
# ...                                   ...    ...                ...
# 19692                                 290  30-34             Female
# 19694                                 111  25-29               Male
# 19704                                 346  22-24               Male
# 19710                                  88  25-29  Prefer not to say
# 19711                                  85  22-24               Male
#
#       Q2_OTHER_TEXT       Q3                                    Q4  \
# 6                -1   France                       Master’s degree
# 7                -1    India                       Master’s degree
# 13               -1  Germany                     Bachelor’s degree
# 32               -1    Japan                       Master’s degree
# 35               -1   Brazil                     Bachelor’s degree
# ...             ...      ...                                   ...
# 19692            -1    India                       Master’s degree
# 19694            -1    India                       Master’s degree
# 19704            -1    India                     Bachelor’s degree
# 19710            -1  Austria  No formal education past high school
# 19711            -1    India                     Bachelor’s degree
#
#                    Q5 Q5_OTHER_TEXT                  Q6     Q7  ...  \
# 6      Data Scientist            -1      0-49 employees    3-4  ...
# 7      Data Scientist            -1    50-249 employees    20+  ...
# 13     Data Scientist            -1    50-249 employees    5-9  ...
# 32     Data Scientist            -1      0-49 employees  10-14  ...
# 35     Data Scientist            -1  > 10,000 employees    1-2  ...
# ...               ...           ...                 ...    ...  ...
# 19692  Data Scientist            -1  > 10,000 employees  15-19  ...
# 19694  Data Scientist            -1      0-49 employees    3-4  ...
# 19704  Data Scientist            -1    50-249 employees    3-4  ...
# 19710  Data Scientist            -1   250-999 employees    1-2  ...
# 19711  Data Scientist            -1    50-249 employees    NaN  ...
#
#       Q34_Part_4       Q34_Part_5 Q34_Part_6                       Q34_Part_7  \
# 6            NaN              NaN        NaN  AWS Relational Database Service
# 7            NaN              NaN        NaN                              NaN
# 13           NaN              NaN        NaN                              NaN
# 32           NaN              NaN        NaN                              NaN
# 35           NaN  Oracle Database        NaN                              NaN
# ...          ...              ...        ...                              ...
# 19692        NaN              NaN        NaN                              NaN
# 19694        NaN              NaN        NaN                              NaN
# 19704        NaN              NaN        NaN                              NaN
# 19710        NaN              NaN        NaN                              NaN
# 19711        NaN              NaN        NaN                              NaN
#
#       Q34_Part_8 Q34_Part_9 Q34_Part_10 Q34_Part_11 Q34_Part_12 Q34_OTHER_TEXT
# 6            NaN        NaN         NaN         NaN         NaN             -1
# 7            NaN        NaN         NaN         NaN         NaN             -1
# 13           NaN        NaN         NaN         NaN         NaN             -1
# 32           NaN        NaN         NaN         NaN         NaN             -1
# 35           NaN        NaN         NaN         NaN         NaN             -1
# ...          ...        ...         ...         ...         ...            ...
# 19692        NaN        NaN         NaN         NaN         NaN             -1
# 19694        NaN        NaN         NaN         NaN         NaN             -1
# 19704        NaN        NaN         NaN         NaN         NaN             -1
# 19710        NaN        NaN         NaN         NaN         NaN             -1
# 19711        NaN        NaN         NaN         NaN         NaN             -1
#
# [2867 rows x 246 columns]
